# %% [markdown]
# ### Multiple Linear Regression
# # y' = b0 + b1X1 + b2X2 +....+ bn+Xn

# %% [markdown]
# ### 5 methods of building models:
# 1. All-in
# 2. Backward Elimination
# 3. Forward Selection
# 4. Birdirectional Elimination
# 5. Score Comparison
#
# step 2,3 & 4 are Stepwise Regression
